# %%
import pandas as pd
import numpy as np

# %%
import sklearn.feature_extraction
sklearn.__version__
# Out:
# '0.19.1'

# %%
# %matplotlib inline
from matplotlib import pylab
from pylab import *

# %%
# Version 0.12.0 of Pandas has a DeprecationWarning about Height blah that I'm ignoring
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Set default pylab stuff# Set de 
pylab.rcParams['figure.figsize'] = (5.0, 4.0)
pylab.rcParams['axes.grid'] = True

# %%
train = pd.read_csv('dgcorrect1/bin/pre/testing1.csv')

# %%
train
# Out:
#                                                        uri  class
# 0                                             vkxynazg.top    dga
# 1                         r1---sn-nv47lne6.googlevideo.com  legit
# 2                                              rfwtlxl.com  legit
# 3                                            fikratona.com  legit
# 4                                           iwannarofl.com  legit
# 5                                              mnojwxg.top    dga
# 6                                               inmdata.io  legit
# 7                                      mobile.wal-mart.com  legit
# 8                                            pythomium.net  legit
# 9                                     www.womendisease.com  legit
# 10                                            bidar.nic.in  legit
# 11                                    commondentalcare.com  legit
# 12                                        highfieldabc.com  legit
# 13                                            lovematch.nu  legit
# 14                              securepayments.sberbank.ru  legit
# 15                                           sfdmaps.at.ua  legit
# 16                                signification-prenom.net  legit
# 17                                          m3.iaerfmr.com  legit
# 18                                  canli.ligtvizlesene.me  legit
# 19                                drp-images.nettavisen.no  legit
# 20           tasksprd.failover.arcgisonline.com.akadns.net  legit
# 21                                          m27.lxwaccq.in  legit
# 22                                             icronox.com  legit
# 23                                   healthforceontario.ca  legit
# 24                                      instacartemail.com  legit
# 25                                      bmwmini.demdex.net  legit
# 26                                          nwmsswcpfb.com    dga
# 27                                  exch021.serverdata.net  legit
# 28                                             felslkt.top    dga
# 29                             prd.static.nfh.infra.fih.io  legit
# ...                                                    ...    ...
# 2457377                         f15.w240.photo.talk.zdn.vn  legit
# 2457378                                         queshu.com  legit
# 2457379                          s98iva.storage.yandex.net  legit
# 2457380                                       factorio.com  legit
# 2457381                              permaculturedesign.fr  legit
# 2457382                         clubdemarketingdigital.com  legit
# 2457383  vts-elb-us-2069352210.us-west-2.elb.amazonaws.com  legit
# 2457384                                          ccfccb.cn  legit
# 2457385                                          nt.gov.au  legit
# 2457386                              robertadicamerino.com  legit
# 2457387                                    newturnpike.com  legit
# 2457388                                    pics.smotri.com  legit
# 2457389                              intersection-wifi.net  legit
# 2457390                             e1883.b.akamaiedge.net  legit
# 2457391                              my.starstarmobile.com  legit
# 2457392                                   mobile.ocado.com  legit
# 2457393                               mail1.eventbrite.com  legit
# 2457394                                  telefuturo.com.py  legit
# 2457395                                procuradoramigo.com  legit
# 2457396                                    daystarchina.cn  legit
# 2457397                                     publicbits.com  legit
# 2457398                                    trickglocks.com  legit
# 2457399                                  palmspringsca.gov  legit
# 2457400                                     aoa.demdex.net  legit
# 2457401                              static2.comicvine.com  legit
# 2457402             dailytravel-service.de.multi.uribl.com  legit
# 2457403                                   load.infistar.de  legit
# 2457404                         portal2013br.wordpress.com  legit
# 2457405                                 sojitzamericas.com  legit
# 2457406               static0-srcdn-com.cdn.ampproject.org  legit
#
# [2457407 rows x 2 columns]

# %%
# Okay for this exercise we need the 2LD and nothing else
import tldextract

def domain_extract(uri):
    ext = tldextract.extract(uri)
    if (not ext.suffix):
        return np.nan
    else:
        return ext.domain

train['domain'] = [ domain_extract(uri) for uri in train['uri']]

# %%
# Add a length field for the domain# Add a  
train['length'] = [len(x) for x in train['domain'].astype('str')]

# Okay since we're trying to detect dynamically generated domains and short
# domains (length <=6) are crazy random even for 'legit' domains we're going
# to punt on short domains (perhaps just white/black list for short domains?)
train = train[train['length'] > 6]

# %%
train
# Out:
#                                                        uri  class  \
# 0                                             vkxynazg.top    dga
# 1                         r1---sn-nv47lne6.googlevideo.com  legit
# 2                                              rfwtlxl.com  legit
# 3                                            fikratona.com  legit
# 4                                           iwannarofl.com  legit
# 5                                              mnojwxg.top    dga
# 6                                               inmdata.io  legit
# 7                                      mobile.wal-mart.com  legit
# 8                                            pythomium.net  legit
# 9                                     www.womendisease.com  legit
# 11                                    commondentalcare.com  legit
# 12                                        highfieldabc.com  legit
# 13                                            lovematch.nu  legit
# 14                              securepayments.sberbank.ru  legit
# 16                                signification-prenom.net  legit
# 17                                          m3.iaerfmr.com  legit
# 18                                  canli.ligtvizlesene.me  legit
# 19                                drp-images.nettavisen.no  legit
# 21                                          m27.lxwaccq.in  legit
# 22                                             icronox.com  legit
# 23                                   healthforceontario.ca  legit
# 24                                      instacartemail.com  legit
# 26                                          nwmsswcpfb.com    dga
# 27                                  exch021.serverdata.net  legit
# 28                                             felslkt.top    dga
# 30       rootcs-va001-1132838831.us-east-1.elb.amazonaw...  legit
# 31                  r7---sn-5np5po4v-c33lk.googlevideo.com  legit
# 32                                      picturescream.asia  legit
# 33                                         m11.wqdbife.biz  legit
# 36                                             tcsaims.com  legit
# ...                                                    ...    ...
# 2457363                                  mobi.neweives.com  legit
# 2457364                                        qaemhost.ir  legit
# 2457365                                       financer.com  legit
# 2457368                                    m32.cskhscc.net  legit
# 2457369                                 agrestenoticia.com  legit
# 2457371                                   sabintermedia.ro  legit
# 2457372                                       lagulama.net  legit
# 2457373                                 vernessahimmler.de  legit
# 2457375                            akmc-alshohadahotel.com  legit
# 2457380                                       factorio.com  legit
# 2457381                              permaculturedesign.fr  legit
# 2457382                         clubdemarketingdigital.com  legit
# 2457383  vts-elb-us-2069352210.us-west-2.elb.amazonaws.com  legit
# 2457386                              robertadicamerino.com  legit
# 2457387                                    newturnpike.com  legit
# 2457389                              intersection-wifi.net  legit
# 2457390                             e1883.b.akamaiedge.net  legit
# 2457391                              my.starstarmobile.com  legit
# 2457393                               mail1.eventbrite.com  legit
# 2457394                                  telefuturo.com.py  legit
# 2457395                                procuradoramigo.com  legit
# 2457396                                    daystarchina.cn  legit
# 2457397                                     publicbits.com  legit
# 2457398                                    trickglocks.com  legit
# 2457399                                  palmspringsca.gov  legit
# 2457401                              static2.comicvine.com  legit
# 2457403                                   load.infistar.de  legit
# 2457404                         portal2013br.wordpress.com  legit
# 2457405                                 sojitzamericas.com  legit
# 2457406               static0-srcdn-com.cdn.ampproject.org  legit
#
#                          domain  length
# 0                      vkxynazg       8
# 1                   googlevideo      11
# 2                       rfwtlxl       7
# 3                     fikratona       9
# 4                    iwannarofl      10
# 5                       mnojwxg       7
# 6                       inmdata       7
# 7                      wal-mart       8
# 8                     pythomium       9
# 9                  womendisease      12
# 11             commondentalcare      16
# 12                 highfieldabc      12
# 13                    lovematch       9
# 14                     sberbank       8
# 16         signification-prenom      20
# 17                      iaerfmr       7
# 18                ligtvizlesene      13
# 19                   nettavisen      10
# 21                      lxwaccq       7
# 22                      icronox       7
# 23           healthforceontario      18
# 24               instacartemail      14
# 26                   nwmsswcpfb      10
# 27                   serverdata      10
# 28                      felslkt       7
# 30                    amazonaws       9
# 31                  googlevideo      11
# 32                picturescream      13
# 33                      wqdbife       7
# 36                      tcsaims       7
# ...                         ...     ...
# 2457363                neweives       8
# 2457364                qaemhost       8
# 2457365                financer       8
# 2457368                 cskhscc       7
# 2457369          agrestenoticia      14
# 2457371           sabintermedia      13
# 2457372                lagulama       8
# 2457373         vernessahimmler      15
# 2457375     akmc-alshohadahotel      19
# 2457380                factorio       8
# 2457381      permaculturedesign      18
# 2457382  clubdemarketingdigital      22
# 2457383               amazonaws       9
# 2457386       robertadicamerino      17
# 2457387             newturnpike      11
# 2457389       intersection-wifi      17
# 2457390              akamaiedge      10
# 2457391          starstarmobile      14
# 2457393              eventbrite      10
# 2457394              telefuturo      10
# 2457395         procuradoramigo      15
# 2457396            daystarchina      12
# 2457397              publicbits      10
# 2457398             trickglocks      11
# 2457399           palmspringsca      13
# 2457401               comicvine       9
# 2457403                infistar       8
# 2457404               wordpress       9
# 2457405          sojitzamericas      14
# 2457406              ampproject      10
#
# [1817449 rows x 4 columns]

# %%
# Grabbed this from Rosetta Code (rosettacode.org)
import math
from collections import Counter
 
def entropy(s):
    p, lns = Counter(s), float(len(s))
    return -sum( count/lns * math.log(count/lns, 2) for count in p.values())

# %%
# Add a entropy field for the domain
train['entropy'] = [entropy(x) for x in train['domain']]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Boxplots show you the distribution of the data (spread).
# http://en.wikipedia.org/wiki/Box_plot

# Plot the length and entropy of domains
train.boxplot('length','class')
pylab.ylabel('Domain Length')
# Out:
# Text(0,0.5,u'Domain Length')

# %%
train.boxplot('entropy','class')
pylab.ylabel('Domain Entropy')
# Out:
# Text(0,0.5,u'Domain Entropy')

# %%
# Lets plot some stuff!
# Here we want to see whether our new 'alexa_grams' feature can help us differentiate between Legit/DGA
cond = train['class'] == 'dga'
dga = train[cond]
legit = train[~cond]
plt.scatter(legit['length'], legit['entropy'],  s=120, c='#aaaaff', label='Legit', alpha=.2)
plt.scatter(dga['length'], dga['entropy'], s=40, c='r', label='DGA', alpha=.3)
plt.legend()
pylab.xlabel('Domain Length')
pylab.ylabel('Domain Entropy')
# Out:
# Text(0,0.5,u'Domain Entropy')

# %%
# Well our Mom told us we were still cool.. so with that encouragement we're# Well o 
# going to compute NGrams for every Alexa domain and see if we can use the
# NGrams to help us better differentiate and mark DGA domains...

# Scikit learn has a nice NGram generator that can generate either char NGrams or word NGrams (we're using char).
# Parameters: 
#       - ngram_range=(3,5)  # Give me all ngrams of length 3, 4, and 5
#       - min_df=1e-4        # Minimumum document frequency. At 1e-4 we're saying give us NGrams that 
#                            # happen in at least .1% of the domains (so for 100k... at least 100 domains)
alexa_vc = sklearn.feature_extraction.text.CountVectorizer(analyzer='char', ngram_range=(3,5), min_df=1e-4, max_df=1.0)

# %%
# I'm SURE there's a better way to store all the counts but not sure...
# At least the min_df parameters has already done some thresholding
counts_matrix = alexa_vc.fit_transform(train['domain'])
alexa_counts = np.log10(counts_matrix.sum(axis=0).getA1())
ngrams_list = alexa_vc.get_feature_names()

# %%
# For fun sort it and show it
import operator
_sorted_ngrams = sorted(zip(ngrams_list, alexa_counts), key=operator.itemgetter(1), reverse=True)
print 'Legitimate NGrams: %d' % len(_sorted_ngrams)
for ngram, count in _sorted_ngrams[:10]:
    print ngram, count
# Out:
# Legitimate NGrams: 27436
# ide 4.89730812507
# vid 4.84429695896
# deo 4.82482847068
# vide 4.82458137623
# ideo 4.82133007721
# video 4.82009632253
# ing 4.73672309639
# evi 4.72315180591
# goo 4.72246938588
# gle 4.71658757768

# %%
train['alexa_grams']= alexa_counts * alexa_vc.transform(train['domain']).T
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Lets plot some stuff!
# Here we want to see whether our new 'alexa_grams' feature can help us differentiate between Legit/DGA
cond = train['class'] == 'dga'
dga = train[cond]
legit = train[~cond]
plt.scatter(legit['length'], legit['alexa_grams'], s=120, c='#aaaaff', label='Legit', alpha=.1)
plt.scatter(dga['length'], dga['alexa_grams'], s=40, c='r', label='DGA', alpha=.3)
plt.legend()
pylab.xlabel('Domain Length')
pylab.ylabel('Legitimate NGram Matches')
# Out:
# Text(0,0.5,u'Legitimate NGram Matches')

# %%
# Lets plot some stuff!
# Here we want to see whether our new 'alexa_grams' feature can help us differentiate between Legit/DGA
cond = train['class'] == 'dga'
dga = train[cond]
legit = train[~cond]
plt.scatter(legit['entropy'], legit['alexa_grams'],  s=120, c='#aaaaff', label='Legit', alpha=.2)
plt.scatter(dga['entropy'], dga['alexa_grams'], s=40, c='r', label='DGA', alpha=.3)
plt.legend()
pylab.xlabel('Domain Entropy')
pylab.ylabel('Legitimate Gram Matches')
# Out:
# Text(0,0.5,u'Legitimate Gram Matches')
